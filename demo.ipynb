# %% [markdown]
# ###  MicroGrad demo

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from micrograd.engine import Value
from micrograd.nn import Neuron, Layer, MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %%
# make up a dataset

from sklearn.datasets import make_moons, make_blobs
X, y = make_moons(n_samples=100, noise=0.1)

y = y*2 - 1 # make y be -1 or 1
# visualize in 2D
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
# initialize a model 
model = MLP(2, [16, 16, 1]) # 2-layer neural network
print(model)
print("number of parameters", len(model.parameters()))
# Out:
# MLP of [Layer of [ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2)], Layer of [ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16)], Layer of [LinearNeuron(16)]]
# number of parameters 337

# %%
# loss function
def loss(batch_size=None):
    
    # inline DataLoader :)
    if batch_size is None:
        Xb, yb = X, y
    else:
        ri = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[ri], y[ri]
    inputs = [list(map(Value, xrow)) for xrow in Xb]
    
    # forward the model to get scores
    scores = list(map(model, inputs))
    
    # svm "max-margin" loss
    losses = [(1 + -yi*scorei).relu() for yi, scorei in zip(yb, scores)]
    data_loss = sum(losses) * (1.0 / len(losses))
    # L2 regularization
    alpha = 1e-4
    reg_loss = alpha * sum((p*p for p in model.parameters()))
    total_loss = data_loss + reg_loss
    
    # also get accuracy
    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)
# Out:
# Value(data=1.2606891092765604, grad=0) 0.24

# %%
# optimization
for k in range(100):
    
    # forward
    total_loss, acc = loss()
    
    # backward
    model.zero_grad()
    total_loss.backward()
    
    # update (sgd)
    learning_rate = 1.0 - 0.9*k/100
    for p in model.parameters():
        p.data -= learning_rate * p.grad
    
    if k % 1 == 0:
        print(f"step {k} loss {total_loss.data}, accuracy {acc*100}%")
# Out:
# step 0 loss 1.2606891092765604, accuracy 24.0%
# step 1 loss 0.9442463519767779, accuracy 78.0%
# step 2 loss 0.41078667004561353, accuracy 83.0%
# step 3 loss 0.3379238727847243, accuracy 87.0%
# step 4 loss 0.2908982365179929, accuracy 88.0%
# step 5 loss 0.25812466062214995, accuracy 91.0%
# step 6 loss 0.24635683434457764, accuracy 89.0%
# step 7 loss 0.35128563599764, accuracy 90.0%
# step 8 loss 0.5500432035581851, accuracy 82.0%
# step 9 loss 0.4200738714474908, accuracy 86.0%
# step 10 loss 0.2814266511008191, accuracy 87.0%
# step 11 loss 0.2228062826612772, accuracy 89.0%
# step 12 loss 0.1884734066940054, accuracy 92.0%
# step 13 loss 0.20208522257949707, accuracy 92.0%
# step 14 loss 0.20693945579361886, accuracy 92.0%
# step 15 loss 0.2485399967192639, accuracy 90.0%
# step 16 loss 0.16149171548914237, accuracy 92.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       1 # optimization
#       2 for k in range(100):
#       3
#       4     # forward
# ----> 5     total_loss, acc = loss()
#       7     # backward
#       8     model.zero_grad()
#
# Cell In[20], line 13, in loss(batch_size)
#      10 inputs = [list(map(Value, xrow)) for xrow in Xb]
#      12 # forward the model to get scores
# ---> 13 scores = list(map(model, inputs))
#      15 # svm "max-margin" loss
#      16 losses = [(1 + -yi*scorei).relu() for yi, scorei in zip(yb, scores)]
#
# File ~/src/NN-ZeroToHero/micrograd/micrograd/nn.py:53, in MLP.__call__(self, x)
#      51 def __call__(self, x):
#      52     for layer in self.layers:
# ---> 53         x = layer(x)
#      54     return x
#
# File ~/src/NN-ZeroToHero/micrograd/micrograd/nn.py:36, in Layer.__call__(self, x)
#      35 def __call__(self, x):
# ---> 36     out = [n(x) for n in self.neurons]
#      37     return out[0] if len(out) == 1 else out
#
# File ~/src/NN-ZeroToHero/micrograd/micrograd/nn.py:36, in <listcomp>(.0)
#      35 def __call__(self, x):
# ---> 36     out = [n(x) for n in self.neurons]
#      37     return out[0] if len(out) == 1 else out
#
# File ~/src/NN-ZeroToHero/micrograd/micrograd/nn.py:21, in Neuron.__call__(self, x)
#      20 def __call__(self, x):
# ---> 21     act = sum((wi*xi for wi,xi in zip(self.w, x)), self.b)
#      22     return act.relu() if self.nonlin else act
#
# File ~/src/NN-ZeroToHero/micrograd/micrograd/nn.py:21, in <genexpr>(.0)
#      20 def __call__(self, x):
# ---> 21     act = sum((wi*xi for wi,xi in zip(self.w, x)), self.b)
#      22     return act.relu() if self.nonlin else act
#
# File ~/src/NN-ZeroToHero/micrograd/micrograd/engine.py:26, in Value.__mul__(self, other)
#      24 def __mul__(self, other):
#      25     other = other if isinstance(other, Value) else Value(other)
# ---> 26     out = Value(self.data * other.data, (self, other), '*')
#      28     def _backward():
#      29         self.grad += other.data * out.grad
#
# File ~/src/NN-ZeroToHero/micrograd/micrograd/engine.py:10, in Value.__init__(self, data, _children, _op)
#       8 # internal variables used for autograd graph construction
#       9 self._backward = lambda: None
# ---> 10 self._prev = set(_children)
#      11 self._op = _op
#
# KeyboardInterrupt:

# %%
# visualize decision boundary

h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]
inputs = [list(map(Value, xrow)) for xrow in Xmesh]
scores = list(map(model, inputs))
Z = np.array([s.data > 0 for s in scores])
Z = Z.reshape(xx.shape)

fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
# Out:
# (-1.548639298268643, 1.951360701731357)
